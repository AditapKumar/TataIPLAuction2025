# %%
# !pip install pandasai

# %%
from pandasai import SmartDataframe

# %%
import pandas as pd
from pandasai.llm.openai import OpenAI

# %%
Players_Data = pd.read_excel("/content/TATA IPL 2025- Auction List -15.11.24.xlsx")
print(Players_Data)
# Out:
#      List Sr.No.  Set No. 2025 Set  First Name  Surname       Country  \
# 0              1        1       M1         Jos  Buttler       England
# 1              2        1       M1     Shreyas     Iyer         India
# 2              3        1       M1     Rishabh     Pant         India
# 3              4        1       M1      Kagiso   Rabada  South Africa
# 4              5        1       M1    Arshdeep    Singh         India
# ..           ...      ...      ...         ...      ...           ...
# 569          570       79    UAL15  Khrievitso    Kense         India
# 570          571       79    UAL15       Akash   Parkar         India
# 571          572       79    UAL15     Vignesh   Puthur         India
# 572          573       79    UAL15   Tripuresh    Singh         India
# 573          574       79    UAL15       Vijay    Yadav         India
#
#     State Association                  DOB  Age    Specialism  ...  \
# ...

# %%
import os

os.environ['PANDASAI_API_KEY'] = "$2a$10$ux/mNTZHMJR9cmRcexs9MOvuL2SSMZsqJG5DhnaHU/3GwvHyy.w2i"

# %%
Auction_Report = SmartDataframe(Players_Data)

# %% [markdown]
# ### QnA with PandasAI

# %%
Auction_Report.chat("How many players registered for the auction?")
# Out:
# 'The total number of players registered for the auction is 574.'

# %%
Auction_Report.chat("What is the average age of the players?")
# Out:
# 'The average age of the players is 27.28745644599303'

# %%
Auction_Report.chat("How many players are from KSCA(Karanatka State Cricket Association)?")
# Out:
# 24

# %%
Auction_Report.chat("How many players have played for CSK in past?")
# Out:
# 41

# %% [markdown]
# ###Player Distribution by **Specialism**

# %%
Auction_Report.chat("Plot a chart showing the count of players grouped by Specialism (Batter, Bowler, All-rounder, Wicketkeeper).")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 8, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %%
Auction_Report.chat("Which all-rounders are there in the auction?")
# Out:
# 'The all-rounders in the auction are:\nLiam Livingstone from England\nRavichandaran Ashwin from India\nVenkatesh Iyer from India\nMitchell Marsh from Australia\nGlenn Maxwell from Australia\nHarshal Patel from India\nRachin Ravindra from New Zealand\nMarcus Stoinis from Australia\nHarpreet Brar from India\nNaman Dhir from India\nMahipal Lomror from India\nSameer Rizvi from India\nAbdul Samad from India\nVijay Shankar from India\nAshutosh Sharma from India\nNishant Sindhu from India\nUtkarsh Singh from India\nSam Curran from England\nMarco Jansen from South Africa\nDaryl Mitchell from New Zealand\nKrunal Pandya from India\nNitish Rana from India\nWashington Sundar from India\nShardul Thakur from India\nMayank Dagar from India\nAnshul Kamboj from India\nMohd. Arshad Khan from India\nDarshan Nalkande from India\nSuyash Prabhudessai from India\nAnukul Roy from India\nSwapnil Singh from India\nSanvir Singh from India\nShahbaz Ahamad from India\nMoeen Ali from England\nTim David from Austr
# ...

# %%
Auction_Report.chat("How many specialist bowlers are left-handed or right-handed?")
# Out:
# 'Number of specialist bowlers who are left-handed: 55, Number of specialist bowlers who are right-handed: 149'

# %%
Auction_Report.chat("Perform multi-variate analysis on specialism. Give Numbers & percentage on bar")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 13, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %%
Auction_Report.chat("Which player category has more number of players? Give numbers in percentage")
# Out:
# 'The player category with the most number of players is BOWLER with 204 players, which is 35.54% of the total players.'

# %%
Auction_Report.chat("Are there enough all-rounders available for franchises looking to balance their teams?")
# Out:
# 'There are 196 all-rounders available. There are enough all-rounders for franchises looking to balance their teams.'

# %%
Auction_Report.chat("Which specialism has the highest representation in the auction pool?")
# Out:
# 'The specialism with the highest representation in the auction pool is BOWLER.'

# %%
Auction_Report.chat("How many Left arm unorthodox bowlers are there? (It's a very rare category)")
# Out:
# The number of Left arm unorthodox bowlers is: 9
# 9

# %% [markdown]
# ### Age Distribution

# %%
Auction_Report.chat("Plot a chart for number of players born in each decade. Give the numbers")
# Out:
# <string>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 12, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# ...

# %%
Auction_Report.chat("Histogram or box plot to show the age distribution of players, helping franchises target specific age groups.")
# Out:
# <string>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# '/content/exports/charts/temp_chart.png'

# %%
Auction_Report.chat("Plot the chart for Youngest and oldest player in the auction, with names written over bar.")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 10, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %% [markdown]
# ###Capped vs Uncapped Players

# %%
Auction_Report.chat("Pie chart or bar chart comparing the count of capped and uncapped players.")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
Auction_Report.chat("What percentage of uncapped players are below 25 years of age (young prospects)?")
# Out:
# 'The percentage of uncapped players below 25 years of age is 43.94%'

# %%
Auction_Report.chat("Are uncapped players available in specific specialisms (e.g., left-arm bowlers)? Name the players")
# Out:
# 'Uncapped left-arm bowlers available in the auction: Kumar Kartikeya Singh, Manav Suthar, Mukesh Choudhary, Rajan Kumar, Sushant Mishra, Arjun Tendulkar, M. Siddharth, Ashwani Kumar, Abhilash Shetty, Akash Singh, Gurjapneet Singh, Raghav Goyal, Jagadeesha Suchith, Roshan Waghsare, Kuldip Yadav, Prithviraj Yarra, Saumy Pandey, Saurabh Dubey, Kulwant Khejroliya, Naman Tiwari, Ramesh Prasad, Ravi Kumar, Faridoon Dawoodzai, Mujtaba Yousuf, Dipesh Parwani'

# %%
Auction_Report.chat("How does the average reserve price differ between capped and uncapped players?")
# Out:
# 'The average reserve price for capped players is 131.53526970954357 Lakh and for uncapped players is 30.636363636363637 Lakh.'

# %% [markdown]
# ###Reserve (Base) Price Distribution

# %%
Auction_Report.chat("Histogram to show how players are distributed across various reserve price ranges.")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 178, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
Auction_Report.chat("How many players are in the highest reserve price bracket (e.g., 2 Crore)?")
# Out:
# 'The number of players in the highest reserve price bracket (2 Crore) is: 81'

# %%
Auction_Report.chat("Are there affordable players with significant IPL experience (e.g., reserve price <50 Lakh but >50 IPL matches)?")
# Out:
#      List Sr.No.  Set No. 2025 Set First Name  Surname Country  \
# 47            48        8     UBA1      Karun     Nair   India
# 57            58        9     UAL1      Vijay  Shankar   India
# 77            78       12     USP1    Shreyas    Gopal   India
# 326          327       45     UBA5      Manan    Vohra   India
# 432          433       60     UFA7  Siddharth     Kaul   India
#
#     State Association        DOB   Age   Specialism  ...  \
# 47                VCA 1991-06-12  33.0       BATTER  ...
# 57               TNCA 1991-01-26  34.0  ALL-ROUNDER  ...
# 77               KSCA 1993-04-09  31.0       BOWLER  ...
# 326              UTCA 1993-07-18  31.0       BATTER  ...
# 432               PCA 1990-05-19  34.0       BOWLER  ...
#
#               Bowling Type Test caps  ODI caps  T20 caps  IPL  \
# 47      RIGHT ARM Off Spin         0         0         0   76
# 57        RIGHT ARM Medium         0         0         0   72
# ...

# %%
Auction_Report.chat("What’s the average reserve price for each specialism")
# Out:
#               Reserve Price (Rs Lakh)
# Specialism
# ALL-ROUNDER                 67.295918
# BATTER                      73.798077
# BOWLER                      79.093137
# WICKETKEEPER                70.000000

# %% [markdown]
# ### Country Representation

# %%
Auction_Report.chat("Bar chart showing the number of players from each country.")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 8, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %%
Auction_Report.chat("Which countries are supplying the most capped players?")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 9, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %%
Auction_Report.chat("Are there any countries with a significant number of players in the uncapped pool?")
# Out:
#        Country
# India      318

# %%
Auction_Report.chat("What’s the average age of players by country?")
# Out:
#          Country        Age
# 0    Afghanistan  24.666667
# 1      Australia  30.216216
# 2     Bangladesh  26.833333
# 3        England  30.243243
# 4          India  26.002732
# 5        Ireland  25.500000
# 6    New Zealand  29.958333
# 7       Scotland  25.000000
# 8   South Africa  29.612903
# 9      Sri Lanka  27.578947
# 10           USA  32.500000
# 11   West Indies  29.272727
# 12      Zimbabwe  31.000000

# %% [markdown]
# ### Performance Insights

# %%
Auction_Report.chat("Scatter plots to compare Matches IPL 2024 vs. Reserve Price (Rs Lakh) to identify high-value performers.")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
Auction_Report.chat("Bar charts showing total matches played (Test, ODI, T20, IPL) grouped by Specialism.")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
Auction_Report.chat("What’s the correlation between T20 caps and reserve price?")
# Out:
# 'The correlation between T20 caps and reserve price is: 0.6718435127713398'

# %%
Auction_Report.chat("Perform multivariate analysis on performance insights")
# Out:
# <string>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                          List Sr.No.   Set No.       Age  Test caps  ODI caps  \
# List Sr.No.                 1.000000  0.999823 -0.182075  -0.198713 -0.241816
# Set No.                     0.999823  1.000000 -0.182339  -0.199354 -0.242597
# Age                        -0.182075 -0.182339  1.000000   0.401369  0.489037
# Test caps                  -0.198713 -0.199354  0.401369   1.000000  0.751710
# ODI caps                   -0.241816 -0.242597  0.489037   0.751710  1.000000
# T20 caps                   -0.275966 -0.276789  0.457047   0.502268  0.828848
# IPL                        -0.466733 -0.467589  0.452757   0.435633  0.477247
# Matches IPL 2024           -0.582439 -0.581781  0.272131   0.253142  0.302538
# ...

# %% [markdown]
# ### Team-Specific Analysis

# %%
Auction_Report.chat("Stacked bar chart showing the number of players in each 2024 IPL Team grouped by Specialism.")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 9, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %%
Auction_Report.chat("Perform mutlivariate analysis on different teams")
# Out:
#                      Age
# 2024 IPL Team
# CSK            28.095238
# DC             28.272727
# GT             28.045455
# KKR            26.647059
# LSG            29.210526
# MI             27.818182
# Mi             24.000000
# PBKS           29.736842
# RCB            29.105263
# RR             30.411765
# SRH            28.000000
# Unsold         26.376000
