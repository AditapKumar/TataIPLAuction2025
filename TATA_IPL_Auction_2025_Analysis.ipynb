# %%
# !pip install pandasai

# %%
from pandasai import SmartDataframe

# %%
import pandas as pd
from pandasai.llm.openai import OpenAI

# %%
Players_Data = pd.read_excel("/content/TATA IPL 2025- Auction List -15.11.24.xlsx")  # Replace 'file.xlsx' with your file name
print(Players_Data)
# Out:
#      List Sr.No.  Set No. 2025 Set  First Name  Surname       Country  \
# 0              1        1       M1         Jos  Buttler       England
# 1              2        1       M1     Shreyas     Iyer         India
# 2              3        1       M1     Rishabh     Pant         India
# 3              4        1       M1      Kagiso   Rabada  South Africa
# 4              5        1       M1    Arshdeep    Singh         India
# ..           ...      ...      ...         ...      ...           ...
# 569          570       79    UAL15  Khrievitso    Kense         India
# 570          571       79    UAL15       Akash   Parkar         India
# 571          572       79    UAL15     Vignesh   Puthur         India
# 572          573       79    UAL15   Tripuresh    Singh         India
# 573          574       79    UAL15       Vijay    Yadav         India
#
#     State Association                  DOB  Age    Specialism  ...  \
# ...

# %%
import os

os.environ['PANDASAI_API_KEY'] = "$2a$10$BXYBwlSfvMCNvATCCEm1Zup4gVluKA2N4yThsqMwkdM9rhUt3zqbi"

# %%
Auction_Report = SmartDataframe(Players_Data)

# %%
Auction_Report.chat("How many players registered for the auction?")
# Out:
# 'The total number of players registered for the auction is 574.'

# %%
Auction_Report.chat("What is the average age of the players?")
# Out:
# 'The average age of the players is 27.28745644599303.'

# %%
Auction_Report.chat("How many players are having 0 IPL Matches in 2024?")
# Out:
# 424

# %%
Auction_Report.chat("How many players are from KSCA(Karanatka State Cricket Association)?")
# Out:
# 24

# %%
Auction_Report.chat("How many players have played for CSK in past?")
# Out:
# 41

# %%
Auction_Report.chat("Plot a chart for number of players born in each decade. Give the numbers")
# Out:
# <string>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 12, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
# ...

# %%
print(Auction_Report.last_code_executed)
# Out:
# df = pd.concat(dfs)
# df['Year'] = pd.to_datetime(df['DOB']).dt.year
# df['Decade'] = df['Year'] // 10 * 10
# decade_counts = df['Decade'].value_counts().sort_index()
# plt.figure(figsize=(10, 6))
# decade_counts.plot(kind='bar', color='skyblue')
# plt.xlabel('Decade')
# plt.ylabel('Number of Players')
# plt.title('Number of Players Born in Each Decade')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.savefig('/content/exports/charts/temp_chart.png')
# result = {'type': 'plot', 'value': '/content/exports/charts/temp_chart.png'}

# %%
Auction_Report.chat("Plot a line chart for Salary vs Number of Player. Give the numbers on bar")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 13, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# '/content/exports/charts/temp_chart.png'

# %%
Auction_Report.chat("How many players have played for PBKS ")
# Out:
# 65

# %%
Auction_Report.chat("Plot a heatmap on specialism and age of the players.")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
print(Auction_Report.last_code_executed)
# Out:
# df = dfs[0]
# df['Specialism'] = df['Specialism'].str.upper()
# heatmap_data = df.groupby(['Specialism']).size().reset_index(name='Count').sort_values(by='Count', ascending=False)
# plt.figure(figsize=(10, 6))
# sns.heatmap(heatmap_data.pivot('Specialism', 'Count'), annot=True, fmt='g', cmap='coolwarm', cbar=False)
# plt.title('Number of Players by Specialism')
# plt.xlabel('Count')
# plt.ylabel('Specialism')
# plt.tight_layout()
# plt.savefig('/content/exports/charts/temp_chart.png')
# result = {'type': 'plot', 'value': '/content/exports/charts/temp_chart.png'}

# %% [markdown]
# ###Number of Players and Their Countries

# %%
Auction_Report.chat("Plot a chart on players from each country and numbers must be written on the bar.")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 10, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# '/content/exports/charts/temp_chart.png'

# %% [markdown]
# ###Youngest vs Oldest Player

# %%
Auction_Report.chat("Plot the chart for Youngest and oldest player in the auction.")
# Out:
# <string>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 12, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# ...

# %%
Auction_Report.chat("Number of players under the age of 20, between 20 to 25 and 25 to 30.")
# Out:
# 'Number of players under the age of 20: 15, between 20 to 25: 205, and between 25 to 30: 207.'

# %%
Auction_Report.chat("Perform uni-variate analysis on Batting Type and Bowling Type. Display the numbers on bar")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 11, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
# ...

# %%
Auction_Report.chat("Perform mutlivariate analysis.")
# Out:
#    Batting Type              Bowling Type  Count
# 0           LHB               DO NOT BOWL     24
# 1           LHB             LEFT ARM FAST     16
# 2           LHB      LEFT ARM FAST MEDIUM     14
# 3           LHB           LEFT ARM MEDIUM      1
# 4           LHB    LEFT ARM SLOW ORTHODOX     44
# 5           LHB  LEFT ARM SLOW UNORTHODOX      4
# 6           LHB            RIGHT ARM FAST     10
# 7           LHB     RIGHT ARM FAST MEDIUM      9
# 8           LHB        RIGHT ARM LEG SPIN     11
# 9           LHB          RIGHT ARM MEDIUM      3
# 10          LHB        RIGHT ARM OFF SPIN     30
# 11          RHB               DO NOT BOWL     53
# 12          RHB             LEFT ARM FAST      9
# 13          RHB      LEFT ARM FAST MEDIUM      8
# 14          RHB    LEFT ARM SLOW ORTHODOX     14
# 15          RHB  LEFT ARM SLOW UNORTHODOX      5
# 16          RHB            RIGHT ARM FAST     79
# 17          RHB     RIGHT ARM FAST MEDIUM     73
# ...

# %%
Auction_Report.chat("Bowl and their numbers in percentage")
# Out:
#                Bowling Type Percentage
# 0            RIGHT ARM FAST     33.33%
# 1     RIGHT ARM FAST MEDIUM     18.63%
# 2        RIGHT ARM LEG SPIN     16.67%
# 3      LEFT ARM FAST MEDIUM      9.80%
# 4             LEFT ARM FAST      9.80%
# 5    LEFT ARM SLOW ORTHODOX      3.92%
# 6  LEFT ARM SLOW UNORTHODOX      2.94%
# 7        RIGHT ARM OFF SPIN      2.94%
# 8          RIGHT ARM MEDIUM      1.47%
# 9           LEFT ARM MEDIUM      0.49%
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Percentage').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
Auction_Report.chat("Perform multi-variate analysis on specialism. Give Numbers & percentage on bar")
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/pipelines/chat/code_execution.py", line 174, in execute_code
#     exec(code, environment)
#   File "<string>", line 11, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/pandasai/safe_libs/restricted_matplotlib.py", line 75, in __getattr__
#     raise AttributeError(f"'{name}' is not allowed in RestrictedMatplotlib")
# AttributeError: 'tight_layout' is not allowed in RestrictedMatplotlib
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# '/content/exports/charts/temp_chart.png'

# %%
Auction_Report.chat("Which all-rounders are there in the auction? Give Numbers in precentage")
# Out:
# 'The number of all-rounders in the auction is 196 out of 574 players, which is 34.15% of the total.'

# %%
Auction_Report.chat("Which all-rounders are there in the auction?")
# Out:
#      List Sr.No.  Set No. 2025 Set     First Name      Surname    Country  \
# 7              8        2       M2           Liam  Livingstone    ENGLAND
# 19            20        4      AL1  Ravichandaran       Ashwin      INDIA
# 20            21        4      AL1      Venkatesh         Iyer      INDIA
# 21            22        4      AL1       Mitchell        Marsh  AUSTRALIA
# 22            23        4      AL1          Glenn      Maxwell  AUSTRALIA
# ..           ...      ...      ...            ...          ...        ...
# 569          570       79    UAL15     Khrievitso        Kense      INDIA
# 570          571       79    UAL15          Akash       Parkar      INDIA
# 571          572       79    UAL15        Vignesh       Puthur      INDIA
# 572          573       79    UAL15      Tripuresh        Singh      INDIA
# 573          574       79    UAL15          Vijay        Yadav      INDIA
#
#     State Association        DOB  Age   Specialism  ...  \
# ...

# %%
Auction_Report.chat("Which player category has more number of players? Give numbers in percentage")
# Out:
# 'Capped players form 41.99% and Uncapped players form 57.49% of the total players.'
